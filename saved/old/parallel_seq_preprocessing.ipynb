# %%
import csv
import pickle
import sys
import warnings
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.decomposition import PCA
from autosklearn.regression import AutoSklearnRegressor
from joblib import Parallel, delayed
from itertools import product

PATH = '.'
ARCC_PATH = '/home/lmacy1/predictiveml'
# sys.path.append(ARCC_PATH) # if running on ARCC

from modules.feature_methods.main import feature_engineering
from modules.imputation_methods.main import imputation

# %%
# Define the function to process each combination of parameters
def train_model(
    model_type,
    building,
    y_column,
    imputation_method,
    feature_method,
    n_features,
    time_step,
    header,
    data_path,
    add_features,
    min_number_of_days,
    exclude_column,
    n_folds,
    split_rate,
    minutes_per_model,
    memory_limit
):

    out_path = f'{PATH}/models/{model_type}'

    df = pd.read_csv(f'{data_path}/{building}')

    # Convert the data into a Pandas dataframe
    df['ts'] = pd.to_datetime(df['ts'])
    df = df.drop_duplicates(subset=['bldgname', 'ts'])
    df = df.sort_values(['bldgname', 'ts'])

    # Group the dataframe by building name and timestamp
    groups = df.groupby('bldgname')
    df = df.set_index('ts')

    #   print(building)

    # cycle through building names if more than one building per file
    for name, group in groups:
        bldgname = name
        group = group.drop_duplicates(subset=['ts'])

        col_data = group[header]

        # check if column contains the min number of days and is a valid commodity to train on
        if col_data[y_column].count() >= min_number_of_days * 24 and y_column != exclude_column:

            model_data = col_data.copy()
            model_data = model_data.rename(columns={ y_column: 'y', 'ts': 'ds' })
            model_data = model_data.sort_values(['ds'])

            # save the original values into new column
            model_data['y_saved'] = model_data['y']

            # Fill in missing values (preprocessing)
            model_data = imputation(model_data, imputation_method)

            # normalize the data, save orginal data column for graphing later
            scaler = StandardScaler()
            data_scaled = scaler.fit_transform(model_data['y'].values.reshape(-1, 1))
            saved_data_scaled = scaler.fit_transform(model_data['y_saved'].values.reshape(-1, 1))

            # normalize additional features
            add_data_scaled = np.empty((model_data.shape[0], 0))

            for feature in add_features:
                feature_scaler = StandardScaler()
                add_feature_scaled = feature_scaler.fit_transform(model_data[feature].values.reshape(-1, 1))
                add_data_scaled = np.concatenate((add_data_scaled, add_feature_scaled), axis=1)

            # identify most important features and eliminate less important features
            selected_features = feature_engineering(feature_method, n_folds, add_data_scaled, data_scaled, add_features)

            # normalize selected features
            add_data_scaled = np.empty((model_data.shape[0], 0))

            for feature in selected_features:
                feature_scaler = StandardScaler()
                add_feature_scaled = feature_scaler.fit_transform(model_data[feature].values.reshape(-1, 1))
                add_data_scaled = np.concatenate((add_data_scaled, add_feature_scaled), axis=1)

            # handle case where n_features is greater than or equal to selected features
            if (n_features >= add_data_scaled.shape[1]):
                n_features = add_data_scaled.shape[1]

            # train PCA (Linear Dimensionality Reduction) with multi feature output
            pca = PCA(n_components=n_features)
            pca_data = pca.fit_transform(add_data_scaled)
            data_scaled = np.concatenate((data_scaled, pca_data), axis=1)
            
            # split the data into training and testing sets
            train_size = int(len(data_scaled) * split_rate)
            test_size = len(data_scaled) - train_size
            train_data = data_scaled[0:train_size,:]
            test_data = data_scaled[train_size:len(data_scaled),:]
            saved_test_data = saved_data_scaled[train_size:len(data_scaled),:]

            # define the window size
            window_size = time_step

            # create the training and testing data sets
            def create_dataset(dataset, window_size):
                X, y = [], []

                for i in range(window_size, len(dataset)):
                    X.append(dataset[i-window_size:i, :])
                    y.append(dataset[i, 0])
                X, y = np.array(X), np.array(y)
                X = np.reshape(X, (X.shape[0], X.shape[1]*X.shape[2]))
                return X, y

            X_train, y_train = create_dataset(train_data, window_size)
            X_test, y_test = create_dataset(test_data, window_size)
            saved_X_test, saved_y_test = create_dataset(saved_test_data, window_size)

            # reshape the input data
            X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
            X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1]))
            saved_X_test = np.reshape(saved_X_test, (saved_X_test.shape[0], saved_X_test.shape[1]))
            
            # minutes per each model
            time_dist = 60 * minutes_per_model

            # Create the model (solo or ensemble)
            if model_type == 'solos':
                model = AutoSklearnRegressor(
                    time_left_for_this_task=time_dist,
                    memory_limit = memory_limit,
                    ensemble_kwargs = {'ensemble_size': 1}
                )
            elif model_type == 'ensembles':
                model = AutoSklearnRegressor(
                    time_left_for_this_task=time_dist,
                    memory_limit = memory_limit,
                )
            else: 
                print(f'model_type not found: {model_type}')
                sys.exit(0)

            # Train the model
            model.fit(X_train, y_train)
            
            # Predict on the test set
            y_pred = model.predict(X_test)

            # Inverse transform the predictions and actual values
            y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))
            y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
            saved_y_test = scaler.inverse_transform(saved_y_test.reshape(-1, 1))
            y_train = scaler.inverse_transform(y_train.reshape(-1, 1))

            # save the model name
            model_file = f'{out_path}/{bldgname}_{y_column}_{imputation_method}_{feature_method}_{n_features}_{time_step}'
            model_file = model_file.replace(' ', '-').lower()

            # calculate metrics
            print(f'\n{bldgname}, {y_column}, {imputation_method}, {feature_method}, n_features: {n_features}, time_step: {time_step}')
            # print(model.leaderboard())

            nan_mask = np.isnan(saved_y_test)  # boolean mask of NaN values in saved_y_test

            rmse = np.sqrt(mean_squared_error(y_test[~nan_mask], y_pred[~nan_mask]))
            print('RMSE: %.3f' % rmse)

            mae = mean_absolute_error(y_test[~nan_mask], y_pred[~nan_mask])
            print('MAE: %.3f' % mae)

            r2 = r2_score(y_test[~nan_mask], y_pred[~nan_mask])
            print('R2: %.3f' % r2)

            # return results
            return (model_type, bldgname, y_column, imputation_method, feature_method, n_features, time_step, rmse, mae, r2, model_file)

# %%
if __name__ == '__main__':

    # Settings
    data_path = f'{PATH}/clean_data_extended'
    buildings_list = ['Stadium_Data_Extended.csv']
    save_model_file = False
    save_model_plot = False
    min_number_of_days = 365
    memory_limit = 102400
    exclude_column = 'present_co2_tonh'
    warnings.filterwarnings("ignore")

    y_columns = ['present_elec_kwh', 'present_htwt_mmbtuh', 'present_wtr_usgal', 'present_chll_tonh', 'present_co2_tonh']
    add_features = ['temp_c', 'rel_humidity_%', 'surface_pressure_hpa', 'cloud_cover_%', 'direct_radiation_w/m2', 'precipitation_mm', 'wind_speed_ground_km/h', 'wind_dir_ground_deg']
    header = ['ts'] + y_columns + add_features

    # Training scope
    models = {}
    model_types = ['ensembles', 'solos']
    imputation_methods = ['linear_regression', 'linear_interpolation', 'prophet', 'lstm']
    feature_methods = ['rfecv', 'lassocv']

    # Hyperparameters
    n_features = list(range(1, len(add_features)))
    n_folds = 5
    time_steps = [1, 8, 12, 24]
    minutes_per_model = 2
    split_rate = 0.8

    # Generate a list of arguments for model training
    arguments = list(product(
        model_types,
        buildings_list,
        y_columns,
        imputation_methods,
        feature_methods,
        n_features,
        time_steps,
        [header],
        [data_path],
        [add_features],
        [min_number_of_days],
        [exclude_column],
        [n_folds],
        [split_rate],
        [minutes_per_model],
        [memory_limit]
    ))

    # Execute the training function in parallel for each set of arguments
    results = Parallel(n_jobs=-1, prefer="processes")(delayed(train_model)(*arg) for arg in arguments)

    # Create a CSV file to save the results
    results_header = ['model_type', 'bldgname', 'y_column', 'imputation_method', 'feature_method', 'n_features', 'time_step', 'rmse', 'mae', 'r2', 'model_file']

    # Save the results to the CSV file
    with open(f'{PATH}/results.csv', mode='w') as results_file:
        writer = csv.writer(results_file)
        writer.writerow(results_header)
        writer.writerows(results)
# Out:
# 2023-06-05 16:49:21.464190: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.494187: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.545568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.683053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.684312: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.762141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.807516: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.827528: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.835507: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.859945: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.895276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.922406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.938775: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.945115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.945390: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.978318: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:21.997577: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.031646: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.039266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.039349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.052226: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.077309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.117122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-05 16:49:22.686560: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [WARNING] [2023-06-05 16:49:38,617:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,629:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,796:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,884:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,896:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,901:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:38,963:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,105:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,111:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,164:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,322:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,449:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,460:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,538:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,627:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,666:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,703:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,727:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,770:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,795:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:39,894:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:40,145:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:40,151:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:40,493:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:43,347:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:43,461:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:49:59,092:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:10,060:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:10,216:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:10,278:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:10,284:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:10,482:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:14,137:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:14,554:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:14,554:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:14,556:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:14,579:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:50:47,624:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:12,949:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:12,967:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:13,981:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:13,982:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:13,985:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,079:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,101:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,104:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,105:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,108:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,109:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,111:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,123:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:14,128:Client-EnsembleBuilder] No runs were available to build an ensemble from
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 1
# RMSE: 39.630
# MAE: 30.438
# R2: 0.655
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 4, time_step: 8
# RMSE: 61.685
# MAE: 54.169
# R2: 0.165
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 4, time_step: 1
# RMSE: 67.539
# MAE: 59.897
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 2, time_step: 1
# RMSE: 41.421
# MAE: 32.254
# R2: 0.623
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 24
# RMSE: 67.594
# MAE: 59.937
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 12
# RMSE: 67.565
# MAE: 59.930
# R2: -0.001
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 3, time_step: 24
# RMSE: 67.594
# MAE: 59.937
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 4, time_step: 24
# RMSE: 67.594
# MAE: 59.937
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 1, time_step: 8
# RMSE: 27.344
# MAE: 17.573
# R2: 0.836
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 1, time_step: 24
# RMSE: 61.627
# MAE: 54.148
# R2: 0.167
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 8
# RMSE: 61.685
# MAE: 54.169
# R2: 0.165
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 8
# RMSE: 61.685
# MAE: 54.169
# R2: 0.165
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 1
# RMSE: 67.539
# MAE: 59.897
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 3, time_step: 1
# RMSE: 67.539
# MAE: 59.897
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 2, time_step: 12
# RMSE: 67.565
# MAE: 59.930
# R2: -0.001
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 3, time_step: 8
# RMSE: 67.552
# MAE: 59.918
# R2: -0.001
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 1, time_step: 12
# RMSE: 67.565
# MAE: 59.930
# R2: -0.001
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 4, time_step: 12
# RMSE: 67.565
# MAE: 59.930
# R2: -0.001
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 2, time_step: 24
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 12
# RMSE: 67.565
# MAE: 59.930
# R2: -0.001
#
#
# RMSE: 67.594
# MAE: 59.937
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 5, time_step: 24
# RMSE: 67.594
# MAE: 59.937
# R2: -0.002
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 3, time_step: 12
# RMSE: 61.713
# MAE: 54.164
# R2: 0.165
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 2, time_step: 8
# RMSE: 27.665
# MAE: 17.849
# R2: 0.832
#
#
# Stadium, present_elec_kwh, linear_regression, rfecv, n_features: 1, time_step: 1
# RMSE: 41.727
# MAE: 32.311
# R2: 0.618
#
#
# [WARNING] [2023-06-05 16:51:31,984:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:33,181:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:33,784:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:34,036:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:34,654:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:34,797:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:34,803:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2023-06-05 16:51:35,076:Client-EnsembleBuilder] No runs were available to build an ensemble from
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 51
#      31 arguments = list(product(
#      32     model_types,
#      33     buildings_list,
#    (...)
#      47     [memory_limit]
#      48 ))
#      50 # Execute the training function in parallel for each set of arguments
# ---> 51 results = Parallel(n_jobs=-1, prefer="processes")(delayed(train_model)(*arg) for arg in arguments)
#      53 # Create a CSV file to save the results
#      54 results_header = ['model_type', 'bldgname', 'y_column', 'imputation_method', 'feature_method', 'n_features', 'time_step', 'rmse', 'mae', 'r2', 'model_file']
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniconda3/envs/tf/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/miniconda3/envs/tf/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
